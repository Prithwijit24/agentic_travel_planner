# %%
from langchain_ollama import ChatOllama
from langchain.messages import AIMessage, HumanMessage

# %%
LLM = ChatOllama(
    model = "deepseek-r1:8b",
    temperature = 0.7
)

# %%
msg = []

# %%
# !uv pip install browser_use_sdk

# %%
LLM.invoke("who are you?")
# Out:
# AIMessage(content="Hi there! 😊 I'm DeepSeek — your friendly AI assistant, here to help you with anything from answering questions and solving problems to helping with creativity, learning, and productivity. You can ask me anything—science, writing, coding, homework help, life advice, you name it!\n\nSo, what can I help you with today? 🌟", additional_kwargs={}, response_metadata={'model': 'deepseek-r1:8b', 'created_at': '2026-02-05T16:33:24.227915887Z', 'done': True, 'done_reason': 'stop', 'total_duration': 75439284945, 'load_duration': 4084975309, 'prompt_eval_count': 6, 'prompt_eval_duration': 758920507, 'eval_count': 298, 'eval_duration': 70368454235, 'logprobs': None, 'model_name': 'deepseek-r1:8b', 'model_provider': 'ollama'}, id='lc_run--019c2ea5-924f-7e91-b2bc-a0b19982e847-0', usage_metadata={'input_tokens': 6, 'output_tokens': 298, 'total_tokens': 304})

# %%
# pip install browser-use-sdk
from browser_use_sdk import BrowserUse
# browser use api key = bu_w4BnR7W20219at2osfMR6HcxgRz6nc6PaIg7-Tejpi8
# Initialize the client with your API key
client = BrowserUse(api_key="bu_U-eAIH-f5Qa4Poz-6DGbw5NTcGm2ukQ9xD8V5z0qiMs")

# Create a task for the browser agent
task = client.tasks.create_task(
    task="Go to browser-use.com/changelog and summarize the latest updates.",
)

# Wait for the task to complete and get the result
result = task.complete()
print(result.output)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 # pip install browser-use-sdk
# ----> 2 from browser_use_sdk import BrowserUse
#       4 # Initialize the client with your API key
#       5 client = BrowserUse(api_key="bu_U-eAIH-f5Qa4Poz-6DGbw5NTcGm2ukQ9xD8V5z0qiMs")
#
# ModuleNotFoundError: No module named 'browser_use_sdk'
