# %%
import sys
sys.executable
# Out:
# '/home/prithwijit/programming/python/imp_projects/tour-planner/agentic_travel_planner/.venv/bin/python'

# %%
import os
from pathlib import Path
from rich import print as rprint

ROOT = Path("/home/prithwijit/programming/python/imp_projects/tour-planner/agentic_travel_planner/src/agentic_tour_planner")
os.chdir(ROOT)

# %%
from retrieval.pipeline import
# Out:
# agents/    graphdb/                                     __pycache__/
# api/       images/                                      retrieval/
# app/       __init__.py                                  sequencing/
# cli/       instructions_and_next_step_implementations/  services/
# config/    llm/                                         storage/
# data/      loading_animations/                          tools/
# domain/    narration/                                   utils/
# geonames/  pipeline/                                    vectordb/

# %%
from vectordb.client import VectorDBClient, get_vector_db
COLLECTION_NAME = "poi_descriptions"
persistent_directory = "data/chroma"

# %%
VDB = VectorDBClient(persist_dir=persistent_directory)

print(f"collection name: {VDB.get_collection()}")
print(f"record count: {VDB.count()}")

collection = VDB.get_collection()
rprint(collection.get())
# Out:
# 2026-08-11 11:36:16 ||| INFO ||| vectordb.client                ||| ChromaDB initialized: data/chroma
# collection name: Collection(name=poi_descriptions)
# record count: 5
# {
#     'ids': [
#         'gangtok__rumtek_monastery',
#         'gangtok__enchey_monastery',
#         'gangtok__taste_of_tibet',
#         'gangtok__the_coffee_shop',
#         'gangtok__mayfair_gangtok'
#     ],
#     'embeddings': None,
#     'documents': [
#         'A Tibetan Buddhist monastery near Gangtok. It is the seat of the Gyalwa Karmapa.',
#         'A 200-year-old monastery with beautiful murals.',
#         'Popular Tibetan restaurant with momos and thukpa.',
#         'Cozy cafe with espresso and pastries.',
#         'Luxury hotel with mountain views.'
#     ],
#     'uris': None,
#     'included': ['metadatas', 'documents'],
#     'data': None,
#     'metadatas': [
#         {
#             'lat': 27.3389,
#             'poi_id': 'gangtok__rumtek_monastery',
# ...

# %%
VDB = get_vector_db()
VDB
# Out:
# 2026-08-11 11:37:13 ||| INFO ||| vectordb.client                ||| ChromaDB initialized: src/agentic_tour_planner/data/chroma
