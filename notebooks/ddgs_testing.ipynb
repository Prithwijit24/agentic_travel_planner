# %%
from ddgs import DDGS

# %%
extract = DDGS().extract("https://www.youtube.com/watch?v=Z2U8Ga4cSTs", fmt = "text_plain")

# %%
print(extract['content'])
# Out:
# Sikkim Tourist Places | Sikkim Itinerary & Sikkim Tour Budget | Sikkim Travel Guide | Gurudongmar -
# YouTube
